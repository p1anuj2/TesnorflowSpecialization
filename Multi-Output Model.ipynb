# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 254.5854 - y1_output_loss: 118.3918 - y2_output_loss: 134.8526 - y1_output_root_mean_squared_error: 10.9169 - y2_output_root_mean_squared_error: 11.6364 - val_loss: 222.1022 - val_y1_output_loss: 45.1415 - val_y2_output_loss: 177.5881 - val_y1_output_root_mean_squared_error: 6.7714 - val_y2_output_root_mean_squared_error: 13.2760
# Epoch 2/500
# 614/614 [==============================] - 0s 155us/sample - loss: 35.5434 - y1_output_loss: 13.1884 - y2_output_loss: 22.0589 - y1_output_root_mean_squared_error: 3.6477 - y2_output_root_mean_squared_error: 4.7156 - val_loss: 35.2091 - val_y1_output_loss: 14.2323 - val_y2_output_loss: 20.9264 - val_y1_output_root_mean_squared_error: 3.8132 - val_y2_output_root_mean_squared_error: 4.5463
# Epoch 3/500
# 614/614 [==============================] - 0s 166us/sample - loss: 26.9758 - y1_output_loss: 10.6783 - y2_output_loss: 16.1082 - y1_output_root_mean_squared_error: 3.2820 - y2_output_root_mean_squared_error: 4.0255 - val_loss: 33.6967 - val_y1_output_loss: 11.4427 - val_y2_output_loss: 22.9068 - val_y1_output_root_mean_squared_error: 3.3992 - val_y2_output_root_mean_squared_error: 4.7056
# Epoch 4/500
# 614/614 [==============================] - 0s 160us/sample - loss: 24.5642 - y1_output_loss: 9.5088 - y2_output_loss: 14.8409 - y1_output_root_mean_squared_error: 3.0983 - y2_output_root_mean_squared_error: 3.8684 - val_loss: 18.3822 - val_y1_output_loss: 8.0396 - val_y2_output_loss: 10.4857 - val_y1_output_root_mean_squared_error: 2.8647 - val_y2_output_root_mean_squared_error: 3.1899
# Epoch 5/500
# 614/614 [==============================] - 0s 143us/sample - loss: 22.4620 - y1_output_loss: 8.9751 - y2_output_loss: 13.5545 - y1_output_root_mean_squared_error: 2.9873 - y2_output_root_mean_squared_error: 3.6794 - val_loss: 46.2323 - val_y1_output_loss: 16.0098 - val_y2_output_loss: 31.6691 - val_y1_output_root_mean_squared_error: 3.9794 - val_y2_output_root_mean_squared_error: 5.5133
# Epoch 6/500
# 614/614 [==============================] - 0s 150us/sample - loss: 22.7182 - y1_output_loss: 8.7471 - y2_output_loss: 13.8974 - y1_output_root_mean_squared_error: 2.9533 - y2_output_root_mean_squared_error: 3.7411 - val_loss: 19.3251 - val_y1_output_loss: 8.4776 - val_y2_output_loss: 10.5130 - val_y1_output_root_mean_squared_error: 2.9530 - val_y2_output_root_mean_squared_error: 3.2565
# Epoch 7/500
# 614/614 [==============================] - 0s 155us/sample - loss: 22.5520 - y1_output_loss: 8.8953 - y2_output_loss: 13.7018 - y1_output_root_mean_squared_error: 2.9858 - y2_output_root_mean_squared_error: 3.6928 - val_loss: 42.2278 - val_y1_output_loss: 10.4724 - val_y2_output_loss: 30.6232 - val_y1_output_root_mean_squared_error: 3.2783 - val_y2_output_root_mean_squared_error: 5.6108
# Epoch 8/500
# 614/614 [==============================] - 0s 150us/sample - loss: 24.5232 - y1_output_loss: 8.9200 - y2_output_loss: 15.8244 - y1_output_root_mean_squared_error: 2.9888 - y2_output_root_mean_squared_error: 3.9485 - val_loss: 21.4073 - val_y1_output_loss: 10.0285 - val_y2_output_loss: 11.2430 - val_y1_output_root_mean_squared_error: 3.1982 - val_y2_output_root_mean_squared_error: 3.3435
# Epoch 9/500
# 614/614 [==============================] - 0s 170us/sample - loss: 22.2619 - y1_output_loss: 8.5176 - y2_output_loss: 13.7676 - y1_output_root_mean_squared_error: 2.9060 - y2_output_root_mean_squared_error: 3.7171 - val_loss: 32.7895 - val_y1_output_loss: 11.8701 - val_y2_output_loss: 19.8926 - val_y1_output_root_mean_squared_error: 3.4930 - val_y2_output_root_mean_squared_error: 4.5375
# Epoch 10/500
# 614/614 [==============================] - 0s 148us/sample - loss: 23.2151 - y1_output_loss: 8.4449 - y2_output_loss: 14.7293 - y1_output_root_mean_squared_error: 2.9082 - y2_output_root_mean_squared_error: 3.8416 - val_loss: 23.4745 - val_y1_output_loss: 8.8213 - val_y2_output_loss: 15.1113 - val_y1_output_root_mean_squared_error: 2.9862 - val_y2_output_root_mean_squared_error: 3.8154
# Epoch 11/500
# 614/614 [==============================] - 0s 142us/sample - loss: 19.9756 - y1_output_loss: 7.7118 - y2_output_loss: 12.1633 - y1_output_root_mean_squared_error: 2.7825 - y2_output_root_mean_squared_error: 3.4976 - val_loss: 20.9948 - val_y1_output_loss: 9.4135 - val_y2_output_loss: 11.6699 - val_y1_output_root_mean_squared_error: 3.0946 - val_y2_output_root_mean_squared_error: 3.3790
# Epoch 12/500
# 614/614 [==============================] - 0s 148us/sample - loss: 20.3543 - y1_output_loss: 7.9358 - y2_output_loss: 12.2822 - y1_output_root_mean_squared_error: 2.8272 - y2_output_root_mean_squared_error: 3.5158 - val_loss: 14.8005 - val_y1_output_loss: 6.7343 - val_y2_output_loss: 7.9235 - val_y1_output_root_mean_squared_error: 2.6264 - val_y2_output_root_mean_squared_error: 2.8111
# Epoch 13/500
# 614/614 [==============================] - 0s 146us/sample - loss: 25.2925 - y1_output_loss: 8.7438 - y2_output_loss: 16.4760 - y1_output_root_mean_squared_error: 2.9537 - y2_output_root_mean_squared_error: 4.0704 - val_loss: 22.4160 - val_y1_output_loss: 11.4819 - val_y2_output_loss: 11.1367 - val_y1_output_root_mean_squared_error: 3.4002 - val_y2_output_root_mean_squared_error: 3.2946
# Epoch 14/500
# 614/614 [==============================] - 0s 151us/sample - loss: 20.7552 - y1_output_loss: 7.8544 - y2_output_loss: 13.0198 - y1_output_root_mean_squared_error: 2.7934 - y2_output_root_mean_squared_error: 3.5989 - val_loss: 15.3850 - val_y1_output_loss: 6.3903 - val_y2_output_loss: 8.7098 - val_y1_output_root_mean_squared_error: 2.5554 - val_y2_output_root_mean_squared_error: 2.9758
# Epoch 15/500
# 614/614 [==============================] - 0s 172us/sample - loss: 17.0265 - y1_output_loss: 6.8207 - y2_output_loss: 10.2466 - y1_output_root_mean_squared_error: 2.5935 - y2_output_root_mean_squared_error: 3.2094 - val_loss: 33.3638 - val_y1_output_loss: 9.9617 - val_y2_output_loss: 24.3611 - val_y1_output_root_mean_squared_error: 3.1534 - val_y2_output_root_mean_squared_error: 4.8394
# Epoch 16/500
# 614/614 [==============================] - 0s 150us/sample - loss: 19.1137 - y1_output_loss: 7.1362 - y2_output_loss: 12.5109 - y1_output_root_mean_squared_error: 2.6482 - y2_output_root_mean_squared_error: 3.4786 - val_loss: 35.7225 - val_y1_output_loss: 7.4285 - val_y2_output_loss: 27.4081 - val_y1_output_root_mean_squared_error: 2.7594 - val_y2_output_root_mean_squared_error: 5.3017
# Epoch 17/500
# 614/614 [==============================] - 0s 149us/sample - loss: 16.9857 - y1_output_loss: 6.3900 - y2_output_loss: 10.7632 - y1_output_root_mean_squared_error: 2.5292 - y2_output_root_mean_squared_error: 3.2540 - val_loss: 46.6411 - val_y1_output_loss: 9.6016 - val_y2_output_loss: 35.9957 - val_y1_output_root_mean_squared_error: 3.1329 - val_y2_output_root_mean_squared_error: 6.0685
# Epoch 18/500
# 614/614 [==============================] - 0s 152us/sample - loss: 20.2195 - y1_output_loss: 7.2642 - y2_output_loss: 12.9611 - y1_output_root_mean_squared_error: 2.6978 - y2_output_root_mean_squared_error: 3.5974 - val_loss: 17.7772 - val_y1_output_loss: 6.7725 - val_y2_output_loss: 10.5422 - val_y1_output_root_mean_squared_error: 2.6422 - val_y2_output_root_mean_squared_error: 3.2857
# Epoch 19/500
# 614/614 [==============================] - 0s 154us/sample - loss: 16.0416 - y1_output_loss: 6.2387 - y2_output_loss: 9.7568 - y1_output_root_mean_squared_error: 2.5068 - y2_output_root_mean_squared_error: 3.1237 - val_loss: 13.8026 - val_y1_output_loss: 5.0794 - val_y2_output_loss: 8.3295 - val_y1_output_root_mean_squared_error: 2.2893 - val_y2_output_root_mean_squared_error: 2.9260
# Epoch 20/500
# 614/614 [==============================] - 0s 161us/sample - loss: 16.6376 - y1_output_loss: 6.3735 - y2_output_loss: 10.1665 - y1_output_root_mean_squared_error: 2.5318 - y2_output_root_mean_squared_error: 3.1981 - val_loss: 16.8243 - val_y1_output_loss: 6.3556 - val_y2_output_loss: 10.0400 - val_y1_output_root_mean_squared_error: 2.5514 - val_y2_output_root_mean_squared_error: 3.2117
# Epoch 21/500
# 614/614 [==============================] - 0s 162us/sample - loss: 16.5921 - y1_output_loss: 6.4332 - y2_output_loss: 10.3237 - y1_output_root_mean_squared_error: 2.5260 - y2_output_root_mean_squared_error: 3.1955 - val_loss: 29.8345 - val_y1_output_loss: 9.5317 - val_y2_output_loss: 20.8990 - val_y1_output_root_mean_squared_error: 3.0962 - val_y2_output_root_mean_squared_error: 4.4998
# Epoch 22/500
# 614/614 [==============================] - 0s 165us/sample - loss: 14.1814 - y1_output_loss: 5.2943 - y2_output_loss: 8.8698 - y1_output_root_mean_squared_error: 2.2997 - y2_output_root_mean_squared_error: 2.9821 - val_loss: 13.2551 - val_y1_output_loss: 4.7813 - val_y2_output_loss: 8.1150 - val_y1_output_root_mean_squared_error: 2.2188 - val_y2_output_root_mean_squared_error: 2.8865
# Epoch 23/500
# 614/614 [==============================] - 0s 149us/sample - loss: 13.5991 - y1_output_loss: 5.3208 - y2_output_loss: 8.2105 - y1_output_root_mean_squared_error: 2.3102 - y2_output_root_mean_squared_error: 2.8744 - val_loss: 19.7839 - val_y1_output_loss: 6.4020 - val_y2_output_loss: 12.7522 - val_y1_output_root_mean_squared_error: 2.5669 - val_y2_output_root_mean_squared_error: 3.6324
# Epoch 24/500
# 614/614 [==============================] - 0s 147us/sample - loss: 12.0899 - y1_output_loss: 4.9102 - y2_output_loss: 7.3377 - y1_output_root_mean_squared_error: 2.1992 - y2_output_root_mean_squared_error: 2.6932 - val_loss: 46.7462 - val_y1_output_loss: 13.6183 - val_y2_output_loss: 33.3930 - val_y1_output_root_mean_squared_error: 3.7208 - val_y2_output_root_mean_squared_error: 5.7360
# Epoch 25/500
# 614/614 [==============================] - 0s 157us/sample - loss: 16.8251 - y1_output_loss: 5.9213 - y2_output_loss: 11.0642 - y1_output_root_mean_squared_error: 2.4038 - y2_output_root_mean_squared_error: 3.3237 - val_loss: 58.9657 - val_y1_output_loss: 18.4362 - val_y2_output_loss: 41.6657 - val_y1_output_root_mean_squared_error: 4.2865 - val_y2_output_root_mean_squared_error: 6.3711
# Epoch 26/500
# 614/614 [==============================] - 0s 163us/sample - loss: 12.8520 - y1_output_loss: 4.9752 - y2_output_loss: 8.0619 - y1_output_root_mean_squared_error: 2.2165 - y2_output_root_mean_squared_error: 2.8177 - val_loss: 10.0635 - val_y1_output_loss: 3.9294 - val_y2_output_loss: 5.8839 - val_y1_output_root_mean_squared_error: 2.0178 - val_y2_output_root_mean_squared_error: 2.4479
# Epoch 27/500
# 614/614 [==============================] - 0s 163us/sample - loss: 12.0873 - y1_output_loss: 4.7560 - y2_output_loss: 7.4577 - y1_output_root_mean_squared_error: 2.1763 - y2_output_root_mean_squared_error: 2.7113 - val_loss: 10.3147 - val_y1_output_loss: 4.0532 - val_y2_output_loss: 6.2392 - val_y1_output_root_mean_squared_error: 2.0420 - val_y2_output_root_mean_squared_error: 2.4789
# Epoch 28/500
# 614/614 [==============================] - 0s 148us/sample - loss: 14.7888 - y1_output_loss: 4.9811 - y2_output_loss: 9.9394 - y1_output_root_mean_squared_error: 2.2190 - y2_output_root_mean_squared_error: 3.1408 - val_loss: 22.1186 - val_y1_output_loss: 8.1328 - val_y2_output_loss: 14.6625 - val_y1_output_root_mean_squared_error: 2.8415 - val_y2_output_root_mean_squared_error: 3.7476
# Epoch 29/500
# 614/614 [==============================] - 0s 184us/sample - loss: 11.3780 - y1_output_loss: 4.3578 - y2_output_loss: 6.9800 - y1_output_root_mean_squared_error: 2.0882 - y2_output_root_mean_squared_error: 2.6490 - val_loss: 10.4754 - val_y1_output_loss: 3.3616 - val_y2_output_loss: 7.1825 - val_y1_output_root_mean_squared_error: 1.8639 - val_y2_output_root_mean_squared_error: 2.6460
# Epoch 30/500
# 614/614 [==============================] - 0s 165us/sample - loss: 10.0177 - y1_output_loss: 3.7539 - y2_output_loss: 6.2814 - y1_output_root_mean_squared_error: 1.9416 - y2_output_root_mean_squared_error: 2.4996 - val_loss: 10.6856 - val_y1_output_loss: 3.4088 - val_y2_output_loss: 6.9163 - val_y1_output_root_mean_squared_error: 1.8769 - val_y2_output_root_mean_squared_error: 2.6764
# Epoch 31/500
# 614/614 [==============================] - 0s 167us/sample - loss: 11.9573 - y1_output_loss: 4.3240 - y2_output_loss: 7.6748 - y1_output_root_mean_squared_error: 2.0834 - y2_output_root_mean_squared_error: 2.7598 - val_loss: 17.1701 - val_y1_output_loss: 3.9861 - val_y2_output_loss: 12.7480 - val_y1_output_root_mean_squared_error: 2.0198 - val_y2_output_root_mean_squared_error: 3.6181
# Epoch 32/500
# 614/614 [==============================] - 0s 186us/sample - loss: 10.6510 - y1_output_loss: 3.7680 - y2_output_loss: 6.8145 - y1_output_root_mean_squared_error: 1.9442 - y2_output_root_mean_squared_error: 2.6213 - val_loss: 8.4228 - val_y1_output_loss: 3.0929 - val_y2_output_loss: 5.3275 - val_y1_output_root_mean_squared_error: 1.7830 - val_y2_output_root_mean_squared_error: 2.2899
# Epoch 33/500
# 614/614 [==============================] - 0s 161us/sample - loss: 8.7213 - y1_output_loss: 3.3723 - y2_output_loss: 5.4851 - y1_output_root_mean_squared_error: 1.8204 - y2_output_root_mean_squared_error: 2.3254 - val_loss: 28.8405 - val_y1_output_loss: 8.5111 - val_y2_output_loss: 21.2743 - val_y1_output_root_mean_squared_error: 2.9030 - val_y2_output_root_mean_squared_error: 4.5181
# Epoch 34/500
# 614/614 [==============================] - 0s 157us/sample - loss: 12.6238 - y1_output_loss: 4.1195 - y2_output_loss: 8.5427 - y1_output_root_mean_squared_error: 2.0282 - y2_output_root_mean_squared_error: 2.9172 - val_loss: 12.7838 - val_y1_output_loss: 3.6781 - val_y2_output_loss: 8.7318 - val_y1_output_root_mean_squared_error: 1.9504 - val_y2_output_root_mean_squared_error: 2.9966
# Epoch 35/500
# 614/614 [==============================] - 0s 147us/sample - loss: 10.1821 - y1_output_loss: 3.7000 - y2_output_loss: 6.5438 - y1_output_root_mean_squared_error: 1.9022 - y2_output_root_mean_squared_error: 2.5620 - val_loss: 9.8739 - val_y1_output_loss: 4.1637 - val_y2_output_loss: 6.0493 - val_y1_output_root_mean_squared_error: 2.0336 - val_y2_output_root_mean_squared_error: 2.3955
# Epoch 36/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.3493 - y1_output_loss: 3.0139 - y2_output_loss: 5.2616 - y1_output_root_mean_squared_error: 1.7443 - y2_output_root_mean_squared_error: 2.3036 - val_loss: 8.0695 - val_y1_output_loss: 2.5127 - val_y2_output_loss: 5.7610 - val_y1_output_root_mean_squared_error: 1.5972 - val_y2_output_root_mean_squared_error: 2.3492
# Epoch 37/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.5957 - y1_output_loss: 3.0753 - y2_output_loss: 5.4486 - y1_output_root_mean_squared_error: 1.7612 - y2_output_root_mean_squared_error: 2.3439 - val_loss: 12.6553 - val_y1_output_loss: 3.1859 - val_y2_output_loss: 9.0262 - val_y1_output_root_mean_squared_error: 1.8160 - val_y2_output_root_mean_squared_error: 3.0590
# Epoch 38/500
# 614/614 [==============================] - 0s 183us/sample - loss: 7.6461 - y1_output_loss: 2.6679 - y2_output_loss: 4.9856 - y1_output_root_mean_squared_error: 1.6289 - y2_output_root_mean_squared_error: 2.2344 - val_loss: 7.0464 - val_y1_output_loss: 2.6414 - val_y2_output_loss: 4.3614 - val_y1_output_root_mean_squared_error: 1.6544 - val_y2_output_root_mean_squared_error: 2.0759
# Epoch 39/500
# 614/614 [==============================] - 0s 152us/sample - loss: 9.1502 - y1_output_loss: 2.8642 - y2_output_loss: 6.2163 - y1_output_root_mean_squared_error: 1.6989 - y2_output_root_mean_squared_error: 2.5028 - val_loss: 7.3647 - val_y1_output_loss: 2.3078 - val_y2_output_loss: 5.2663 - val_y1_output_root_mean_squared_error: 1.5269 - val_y2_output_root_mean_squared_error: 2.2435
# Epoch 40/500
# 614/614 [==============================] - 0s 150us/sample - loss: 10.5538 - y1_output_loss: 3.5479 - y2_output_loss: 6.9891 - y1_output_root_mean_squared_error: 1.8732 - y2_output_root_mean_squared_error: 2.6543 - val_loss: 12.4534 - val_y1_output_loss: 5.4964 - val_y2_output_loss: 7.2882 - val_y1_output_root_mean_squared_error: 2.3424 - val_y2_output_root_mean_squared_error: 2.6394
# Epoch 41/500
# 614/614 [==============================] - 0s 150us/sample - loss: 7.9101 - y1_output_loss: 2.7549 - y2_output_loss: 5.1029 - y1_output_root_mean_squared_error: 1.6645 - y2_output_root_mean_squared_error: 2.2670 - val_loss: 7.8230 - val_y1_output_loss: 2.4864 - val_y2_output_loss: 5.6218 - val_y1_output_root_mean_squared_error: 1.5780 - val_y2_output_root_mean_squared_error: 2.3093
# Epoch 42/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.1382 - y1_output_loss: 2.7251 - y2_output_loss: 5.5080 - y1_output_root_mean_squared_error: 1.6235 - y2_output_root_mean_squared_error: 2.3457 - val_loss: 16.9300 - val_y1_output_loss: 6.4443 - val_y2_output_loss: 10.9236 - val_y1_output_root_mean_squared_error: 2.5370 - val_y2_output_root_mean_squared_error: 3.2394
# Epoch 43/500
# 614/614 [==============================] - 0s 184us/sample - loss: 7.2133 - y1_output_loss: 2.4016 - y2_output_loss: 4.7923 - y1_output_root_mean_squared_error: 1.5559 - y2_output_root_mean_squared_error: 2.1892 - val_loss: 9.3883 - val_y1_output_loss: 2.9758 - val_y2_output_loss: 6.1580 - val_y1_output_root_mean_squared_error: 1.7514 - val_y2_output_root_mean_squared_error: 2.5142
# Epoch 44/500
# 614/614 [==============================] - 0s 167us/sample - loss: 7.0813 - y1_output_loss: 2.3669 - y2_output_loss: 4.6867 - y1_output_root_mean_squared_error: 1.5427 - y2_output_root_mean_squared_error: 2.1683 - val_loss: 6.8576 - val_y1_output_loss: 2.0183 - val_y2_output_loss: 5.1153 - val_y1_output_root_mean_squared_error: 1.4192 - val_y2_output_root_mean_squared_error: 2.2008
# Epoch 45/500
# 614/614 [==============================] - 0s 157us/sample - loss: 6.8301 - y1_output_loss: 2.4276 - y2_output_loss: 4.4727 - y1_output_root_mean_squared_error: 1.5542 - y2_output_root_mean_squared_error: 2.1011 - val_loss: 18.7119 - val_y1_output_loss: 5.0414 - val_y2_output_loss: 14.6389 - val_y1_output_root_mean_squared_error: 2.2096 - val_y2_output_root_mean_squared_error: 3.7188
# Epoch 46/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.3442 - y1_output_loss: 2.4175 - y2_output_loss: 4.8867 - y1_output_root_mean_squared_error: 1.5531 - y2_output_root_mean_squared_error: 2.2208 - val_loss: 5.4607 - val_y1_output_loss: 1.5967 - val_y2_output_loss: 4.0472 - val_y1_output_root_mean_squared_error: 1.2718 - val_y2_output_root_mean_squared_error: 1.9604
# Epoch 47/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.7136 - y1_output_loss: 1.8662 - y2_output_loss: 3.8788 - y1_output_root_mean_squared_error: 1.3655 - y2_output_root_mean_squared_error: 1.9619 - val_loss: 10.0085 - val_y1_output_loss: 1.7476 - val_y2_output_loss: 7.9142 - val_y1_output_root_mean_squared_error: 1.3429 - val_y2_output_root_mean_squared_error: 2.8644
# Epoch 48/500
# 614/614 [==============================] - 0s 154us/sample - loss: 5.3275 - y1_output_loss: 1.7421 - y2_output_loss: 3.5861 - y1_output_root_mean_squared_error: 1.3170 - y2_output_root_mean_squared_error: 1.8955 - val_loss: 7.0540 - val_y1_output_loss: 1.6471 - val_y2_output_loss: 5.2864 - val_y1_output_root_mean_squared_error: 1.2989 - val_y2_output_root_mean_squared_error: 2.3167
# Epoch 49/500
# 614/614 [==============================] - 0s 163us/sample - loss: 7.2030 - y1_output_loss: 2.1694 - y2_output_loss: 4.9732 - y1_output_root_mean_squared_error: 1.4781 - y2_output_root_mean_squared_error: 2.2402 - val_loss: 7.2318 - val_y1_output_loss: 2.2855 - val_y2_output_loss: 5.4463 - val_y1_output_root_mean_squared_error: 1.4847 - val_y2_output_root_mean_squared_error: 2.2422
# Epoch 50/500
# 614/614 [==============================] - 0s 164us/sample - loss: 5.9328 - y1_output_loss: 1.9685 - y2_output_loss: 3.9429 - y1_output_root_mean_squared_error: 1.4028 - y2_output_root_mean_squared_error: 1.9912 - val_loss: 6.2239 - val_y1_output_loss: 1.8572 - val_y2_output_loss: 4.4806 - val_y1_output_root_mean_squared_error: 1.3545 - val_y2_output_root_mean_squared_error: 2.0950
# Epoch 51/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.4712 - y1_output_loss: 1.7527 - y2_output_loss: 3.6823 - y1_output_root_mean_squared_error: 1.3274 - y2_output_root_mean_squared_error: 1.9259 - val_loss: 5.1745 - val_y1_output_loss: 1.5839 - val_y2_output_loss: 3.7145 - val_y1_output_root_mean_squared_error: 1.2685 - val_y2_output_root_mean_squared_error: 1.8882
# Epoch 52/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.3761 - y1_output_loss: 2.6655 - y2_output_loss: 5.6960 - y1_output_root_mean_squared_error: 1.6291 - y2_output_root_mean_squared_error: 2.3921 - val_loss: 7.9211 - val_y1_output_loss: 1.8636 - val_y2_output_loss: 5.9134 - val_y1_output_root_mean_squared_error: 1.3741 - val_y2_output_root_mean_squared_error: 2.4562
# Epoch 53/500
# 614/614 [==============================] - 0s 152us/sample - loss: 5.0865 - y1_output_loss: 1.6418 - y2_output_loss: 3.4388 - y1_output_root_mean_squared_error: 1.2823 - y2_output_root_mean_squared_error: 1.8553 - val_loss: 6.4602 - val_y1_output_loss: 1.7446 - val_y2_output_loss: 5.0105 - val_y1_output_root_mean_squared_error: 1.3249 - val_y2_output_root_mean_squared_error: 2.1691
# Epoch 54/500
# 614/614 [==============================] - 0s 160us/sample - loss: 5.7318 - y1_output_loss: 1.7955 - y2_output_loss: 3.8930 - y1_output_root_mean_squared_error: 1.3453 - y2_output_root_mean_squared_error: 1.9804 - val_loss: 5.0214 - val_y1_output_loss: 1.2912 - val_y2_output_loss: 3.9216 - val_y1_output_root_mean_squared_error: 1.1445 - val_y2_output_root_mean_squared_error: 1.9265
# Epoch 55/500
# 614/614 [==============================] - 0s 161us/sample - loss: 5.1585 - y1_output_loss: 1.5054 - y2_output_loss: 3.6447 - y1_output_root_mean_squared_error: 1.2268 - y2_output_root_mean_squared_error: 1.9114 - val_loss: 8.3789 - val_y1_output_loss: 2.2802 - val_y2_output_loss: 6.4773 - val_y1_output_root_mean_squared_error: 1.5020 - val_y2_output_root_mean_squared_error: 2.4744
# Epoch 56/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.2824 - y1_output_loss: 1.7197 - y2_output_loss: 3.6260 - y1_output_root_mean_squared_error: 1.3057 - y2_output_root_mean_squared_error: 1.8914 - val_loss: 9.0624 - val_y1_output_loss: 2.0685 - val_y2_output_loss: 6.7121 - val_y1_output_root_mean_squared_error: 1.4614 - val_y2_output_root_mean_squared_error: 2.6319
# Epoch 57/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.9884 - y1_output_loss: 2.1292 - y2_output_loss: 4.9279 - y1_output_root_mean_squared_error: 1.4601 - y2_output_root_mean_squared_error: 2.2037 - val_loss: 6.2210 - val_y1_output_loss: 1.2855 - val_y2_output_loss: 4.7465 - val_y1_output_root_mean_squared_error: 1.1512 - val_y2_output_root_mean_squared_error: 2.2126
# Epoch 58/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.1964 - y1_output_loss: 1.4889 - y2_output_loss: 3.7317 - y1_output_root_mean_squared_error: 1.2212 - y2_output_root_mean_squared_error: 1.9248 - val_loss: 7.1850 - val_y1_output_loss: 1.7788 - val_y2_output_loss: 5.2674 - val_y1_output_root_mean_squared_error: 1.3506 - val_y2_output_root_mean_squared_error: 2.3154
# Epoch 59/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.1616 - y1_output_loss: 1.7572 - y2_output_loss: 4.3808 - y1_output_root_mean_squared_error: 1.3298 - y2_output_root_mean_squared_error: 2.0960 - val_loss: 5.9297 - val_y1_output_loss: 1.8398 - val_y2_output_loss: 4.4890 - val_y1_output_root_mean_squared_error: 1.3354 - val_y2_output_root_mean_squared_error: 2.0363
# Epoch 60/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.1376 - y1_output_loss: 1.4326 - y2_output_loss: 3.6600 - y1_output_root_mean_squared_error: 1.2025 - y2_output_root_mean_squared_error: 1.9213 - val_loss: 6.2294 - val_y1_output_loss: 1.4288 - val_y2_output_loss: 4.6426 - val_y1_output_root_mean_squared_error: 1.2151 - val_y2_output_root_mean_squared_error: 2.1801
# Epoch 61/500
# 614/614 [==============================] - 0s 154us/sample - loss: 10.3120 - y1_output_loss: 2.9976 - y2_output_loss: 7.2541 - y1_output_root_mean_squared_error: 1.7332 - y2_output_root_mean_squared_error: 2.7034 - val_loss: 5.3637 - val_y1_output_loss: 1.7275 - val_y2_output_loss: 3.6834 - val_y1_output_root_mean_squared_error: 1.3215 - val_y2_output_root_mean_squared_error: 1.9019
# Epoch 62/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.3423 - y1_output_loss: 1.3034 - y2_output_loss: 3.0228 - y1_output_root_mean_squared_error: 1.1364 - y2_output_root_mean_squared_error: 1.7467 - val_loss: 4.5358 - val_y1_output_loss: 1.6029 - val_y2_output_loss: 3.0960 - val_y1_output_root_mean_squared_error: 1.2514 - val_y2_output_root_mean_squared_error: 1.7233
# Epoch 63/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.6881 - y1_output_loss: 1.2838 - y2_output_loss: 3.3912 - y1_output_root_mean_squared_error: 1.1364 - y2_output_root_mean_squared_error: 1.8430 - val_loss: 4.3508 - val_y1_output_loss: 0.9140 - val_y2_output_loss: 3.4821 - val_y1_output_root_mean_squared_error: 0.9539 - val_y2_output_root_mean_squared_error: 1.8550
# Epoch 64/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.6377 - y1_output_loss: 1.2297 - y2_output_loss: 3.4259 - y1_output_root_mean_squared_error: 1.1126 - y2_output_root_mean_squared_error: 1.8438 - val_loss: 4.0621 - val_y1_output_loss: 1.1022 - val_y2_output_loss: 3.1042 - val_y1_output_root_mean_squared_error: 1.0401 - val_y2_output_root_mean_squared_error: 1.7264
# Epoch 65/500
# 614/614 [==============================] - 0s 143us/sample - loss: 12.6539 - y1_output_loss: 3.6452 - y2_output_loss: 8.9335 - y1_output_root_mean_squared_error: 1.9117 - y2_output_root_mean_squared_error: 2.9999 - val_loss: 6.4719 - val_y1_output_loss: 2.3764 - val_y2_output_loss: 4.0494 - val_y1_output_root_mean_squared_error: 1.5622 - val_y2_output_root_mean_squared_error: 2.0078
# Epoch 66/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.5909 - y1_output_loss: 1.3140 - y2_output_loss: 3.2424 - y1_output_root_mean_squared_error: 1.1507 - y2_output_root_mean_squared_error: 1.8074 - val_loss: 6.0047 - val_y1_output_loss: 0.9915 - val_y2_output_loss: 5.2409 - val_y1_output_root_mean_squared_error: 1.0059 - val_y2_output_root_mean_squared_error: 2.2345
# Epoch 67/500
# 614/614 [==============================] - 0s 151us/sample - loss: 5.1213 - y1_output_loss: 1.1846 - y2_output_loss: 3.9045 - y1_output_root_mean_squared_error: 1.0919 - y2_output_root_mean_squared_error: 1.9822 - val_loss: 5.0690 - val_y1_output_loss: 1.5448 - val_y2_output_loss: 3.7089 - val_y1_output_root_mean_squared_error: 1.2474 - val_y2_output_root_mean_squared_error: 1.8743
# Epoch 68/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.4737 - y1_output_loss: 1.6962 - y2_output_loss: 3.7605 - y1_output_root_mean_squared_error: 1.3060 - y2_output_root_mean_squared_error: 1.9412 - val_loss: 6.6655 - val_y1_output_loss: 0.8712 - val_y2_output_loss: 5.6555 - val_y1_output_root_mean_squared_error: 0.9317 - val_y2_output_root_mean_squared_error: 2.4078
# Epoch 69/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.4984 - y1_output_loss: 0.9925 - y2_output_loss: 2.5943 - y1_output_root_mean_squared_error: 0.9976 - y2_output_root_mean_squared_error: 1.5822 - val_loss: 10.3303 - val_y1_output_loss: 1.6858 - val_y2_output_loss: 9.0441 - val_y1_output_root_mean_squared_error: 1.2961 - val_y2_output_root_mean_squared_error: 2.9412
# Epoch 70/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.9171 - y1_output_loss: 1.3316 - y2_output_loss: 3.6866 - y1_output_root_mean_squared_error: 1.1584 - y2_output_root_mean_squared_error: 1.8909 - val_loss: 12.4609 - val_y1_output_loss: 2.1764 - val_y2_output_loss: 10.7579 - val_y1_output_root_mean_squared_error: 1.4718 - val_y2_output_root_mean_squared_error: 3.2085
# Epoch 71/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.1475 - y1_output_loss: 0.9312 - y2_output_loss: 3.2026 - y1_output_root_mean_squared_error: 0.9572 - y2_output_root_mean_squared_error: 1.7975 - val_loss: 3.5228 - val_y1_output_loss: 0.8224 - val_y2_output_loss: 2.8145 - val_y1_output_root_mean_squared_error: 0.9082 - val_y2_output_root_mean_squared_error: 1.6426
# Epoch 72/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.2106 - y1_output_loss: 1.0220 - y2_output_loss: 3.1953 - y1_output_root_mean_squared_error: 1.0106 - y2_output_root_mean_squared_error: 1.7859 - val_loss: 5.5856 - val_y1_output_loss: 1.5960 - val_y2_output_loss: 4.2626 - val_y1_output_root_mean_squared_error: 1.2551 - val_y2_output_root_mean_squared_error: 2.0026
# Epoch 73/500
# 614/614 [==============================] - 0s 152us/sample - loss: 7.7573 - y1_output_loss: 2.4420 - y2_output_loss: 5.2861 - y1_output_root_mean_squared_error: 1.5679 - y2_output_root_mean_squared_error: 2.3019 - val_loss: 4.3036 - val_y1_output_loss: 1.0207 - val_y2_output_loss: 3.2245 - val_y1_output_root_mean_squared_error: 1.0226 - val_y2_output_root_mean_squared_error: 1.8050
# Epoch 74/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.1375 - y1_output_loss: 0.9688 - y2_output_loss: 3.1438 - y1_output_root_mean_squared_error: 0.9881 - y2_output_root_mean_squared_error: 1.7780 - val_loss: 3.1520 - val_y1_output_loss: 0.6249 - val_y2_output_loss: 2.4760 - val_y1_output_root_mean_squared_error: 0.7990 - val_y2_output_root_mean_squared_error: 1.5854
# Epoch 75/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.8015 - y1_output_loss: 0.8937 - y2_output_loss: 2.8901 - y1_output_root_mean_squared_error: 0.9464 - y2_output_root_mean_squared_error: 1.7047 - val_loss: 2.8995 - val_y1_output_loss: 0.7164 - val_y2_output_loss: 2.1941 - val_y1_output_root_mean_squared_error: 0.8609 - val_y2_output_root_mean_squared_error: 1.4691
# Epoch 76/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.3747 - y1_output_loss: 0.7790 - y2_output_loss: 2.5723 - y1_output_root_mean_squared_error: 0.8862 - y2_output_root_mean_squared_error: 1.6091 - val_loss: 3.4499 - val_y1_output_loss: 0.6993 - val_y2_output_loss: 2.7610 - val_y1_output_root_mean_squared_error: 0.8409 - val_y2_output_root_mean_squared_error: 1.6561
# Epoch 77/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.5408 - y1_output_loss: 1.0707 - y2_output_loss: 2.4779 - y1_output_root_mean_squared_error: 1.0381 - y2_output_root_mean_squared_error: 1.5695 - val_loss: 3.9096 - val_y1_output_loss: 0.8727 - val_y2_output_loss: 3.1624 - val_y1_output_root_mean_squared_error: 0.9355 - val_y2_output_root_mean_squared_error: 1.7420
# Epoch 78/500
# 614/614 [==============================] - 0s 157us/sample - loss: 4.5011 - y1_output_loss: 1.0081 - y2_output_loss: 3.4585 - y1_output_root_mean_squared_error: 1.0087 - y2_output_root_mean_squared_error: 1.8665 - val_loss: 4.2319 - val_y1_output_loss: 0.9750 - val_y2_output_loss: 3.1227 - val_y1_output_root_mean_squared_error: 0.9959 - val_y2_output_root_mean_squared_error: 1.8000
# Epoch 79/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.4030 - y1_output_loss: 0.8568 - y2_output_loss: 2.5502 - y1_output_root_mean_squared_error: 0.9183 - y2_output_root_mean_squared_error: 1.5999 - val_loss: 4.5630 - val_y1_output_loss: 1.5732 - val_y2_output_loss: 3.1609 - val_y1_output_root_mean_squared_error: 1.2331 - val_y2_output_root_mean_squared_error: 1.7442
# Epoch 80/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.8934 - y1_output_loss: 1.3030 - y2_output_loss: 3.5785 - y1_output_root_mean_squared_error: 1.1430 - y2_output_root_mean_squared_error: 1.8939 - val_loss: 5.8122 - val_y1_output_loss: 0.5925 - val_y2_output_loss: 5.3429 - val_y1_output_root_mean_squared_error: 0.7827 - val_y2_output_root_mean_squared_error: 2.2803
# Epoch 81/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.0366 - y1_output_loss: 0.6931 - y2_output_loss: 2.3657 - y1_output_root_mean_squared_error: 0.8264 - y2_output_root_mean_squared_error: 1.5342 - val_loss: 8.3392 - val_y1_output_loss: 2.5910 - val_y2_output_loss: 5.9629 - val_y1_output_root_mean_squared_error: 1.6094 - val_y2_output_root_mean_squared_error: 2.3977
# Epoch 82/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.6036 - y1_output_loss: 0.9347 - y2_output_loss: 2.6369 - y1_output_root_mean_squared_error: 0.9705 - y2_output_root_mean_squared_error: 1.6315 - val_loss: 2.7560 - val_y1_output_loss: 0.4576 - val_y2_output_loss: 2.3195 - val_y1_output_root_mean_squared_error: 0.6820 - val_y2_output_root_mean_squared_error: 1.5136
# Epoch 83/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.4362 - y1_output_loss: 0.7999 - y2_output_loss: 2.6153 - y1_output_root_mean_squared_error: 0.8969 - y2_output_root_mean_squared_error: 1.6223 - val_loss: 4.7624 - val_y1_output_loss: 1.1788 - val_y2_output_loss: 3.7015 - val_y1_output_root_mean_squared_error: 1.0915 - val_y2_output_root_mean_squared_error: 1.8897
# Epoch 84/500
# 614/614 [==============================] - 0s 172us/sample - loss: 3.4286 - y1_output_loss: 0.8660 - y2_output_loss: 2.5991 - y1_output_root_mean_squared_error: 0.9306 - y2_output_root_mean_squared_error: 1.6008 - val_loss: 15.7460 - val_y1_output_loss: 3.4155 - val_y2_output_loss: 11.8950 - val_y1_output_root_mean_squared_error: 1.8652 - val_y2_output_root_mean_squared_error: 3.5025
# Epoch 85/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.9609 - y1_output_loss: 0.9316 - y2_output_loss: 3.0145 - y1_output_root_mean_squared_error: 0.9647 - y2_output_root_mean_squared_error: 1.7408 - val_loss: 5.1870 - val_y1_output_loss: 1.6459 - val_y2_output_loss: 3.4262 - val_y1_output_root_mean_squared_error: 1.2805 - val_y2_output_root_mean_squared_error: 1.8834
# Epoch 86/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.3565 - y1_output_loss: 0.7484 - y2_output_loss: 2.5891 - y1_output_root_mean_squared_error: 0.8681 - y2_output_root_mean_squared_error: 1.6134 - val_loss: 3.5078 - val_y1_output_loss: 0.7465 - val_y2_output_loss: 2.9080 - val_y1_output_root_mean_squared_error: 0.8622 - val_y2_output_root_mean_squared_error: 1.6627
# Epoch 87/500
# 614/614 [==============================] - 0s 157us/sample - loss: 4.3302 - y1_output_loss: 0.9630 - y2_output_loss: 3.3480 - y1_output_root_mean_squared_error: 0.9795 - y2_output_root_mean_squared_error: 1.8360 - val_loss: 3.5575 - val_y1_output_loss: 0.9785 - val_y2_output_loss: 2.5246 - val_y1_output_root_mean_squared_error: 0.9925 - val_y2_output_root_mean_squared_error: 1.6039
# Epoch 88/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.2841 - y1_output_loss: 0.6671 - y2_output_loss: 2.5965 - y1_output_root_mean_squared_error: 0.8165 - y2_output_root_mean_squared_error: 1.6178 - val_loss: 2.5983 - val_y1_output_loss: 0.5964 - val_y2_output_loss: 2.0075 - val_y1_output_root_mean_squared_error: 0.7800 - val_y2_output_root_mean_squared_error: 1.4106
# Epoch 89/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.8567 - y1_output_loss: 0.6143 - y2_output_loss: 2.2235 - y1_output_root_mean_squared_error: 0.7869 - y2_output_root_mean_squared_error: 1.4958 - val_loss: 3.2366 - val_y1_output_loss: 0.7958 - val_y2_output_loss: 2.4603 - val_y1_output_root_mean_squared_error: 0.9055 - val_y2_output_root_mean_squared_error: 1.5546
# Epoch 90/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.7659 - y1_output_loss: 0.6604 - y2_output_loss: 2.0850 - y1_output_root_mean_squared_error: 0.8130 - y2_output_root_mean_squared_error: 1.4508 - val_loss: 2.7937 - val_y1_output_loss: 0.4877 - val_y2_output_loss: 2.2462 - val_y1_output_root_mean_squared_error: 0.7108 - val_y2_output_root_mean_squared_error: 1.5128
# Epoch 91/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.4257 - y1_output_loss: 0.9149 - y2_output_loss: 2.5247 - y1_output_root_mean_squared_error: 0.9469 - y2_output_root_mean_squared_error: 1.5903 - val_loss: 3.1792 - val_y1_output_loss: 0.7574 - val_y2_output_loss: 2.4096 - val_y1_output_root_mean_squared_error: 0.8740 - val_y2_output_root_mean_squared_error: 1.5541
# Epoch 92/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.4851 - y1_output_loss: 0.5203 - y2_output_loss: 1.9594 - y1_output_root_mean_squared_error: 0.7227 - y2_output_root_mean_squared_error: 1.4010 - val_loss: 3.8209 - val_y1_output_loss: 0.8813 - val_y2_output_loss: 2.8989 - val_y1_output_root_mean_squared_error: 0.9350 - val_y2_output_root_mean_squared_error: 1.7166
# Epoch 93/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.9214 - y1_output_loss: 0.6711 - y2_output_loss: 2.2386 - y1_output_root_mean_squared_error: 0.8202 - y2_output_root_mean_squared_error: 1.4995 - val_loss: 2.5483 - val_y1_output_loss: 0.3992 - val_y2_output_loss: 2.1154 - val_y1_output_root_mean_squared_error: 0.6420 - val_y2_output_root_mean_squared_error: 1.4616
# Epoch 94/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.6254 - y1_output_loss: 0.5718 - y2_output_loss: 2.0417 - y1_output_root_mean_squared_error: 0.7554 - y2_output_root_mean_squared_error: 1.4334 - val_loss: 2.6556 - val_y1_output_loss: 0.4817 - val_y2_output_loss: 2.1604 - val_y1_output_root_mean_squared_error: 0.7016 - val_y2_output_root_mean_squared_error: 1.4708
# Epoch 95/500
# 614/614 [==============================] - 0s 175us/sample - loss: 2.2906 - y1_output_loss: 0.5264 - y2_output_loss: 1.7853 - y1_output_root_mean_squared_error: 0.7220 - y2_output_root_mean_squared_error: 1.3302 - val_loss: 8.6921 - val_y1_output_loss: 0.7442 - val_y2_output_loss: 8.2142 - val_y1_output_root_mean_squared_error: 0.8694 - val_y2_output_root_mean_squared_error: 2.8171
# Epoch 96/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.4756 - y1_output_loss: 0.7387 - y2_output_loss: 2.7088 - y1_output_root_mean_squared_error: 0.8628 - y2_output_root_mean_squared_error: 1.6526 - val_loss: 2.7124 - val_y1_output_loss: 0.4347 - val_y2_output_loss: 2.3208 - val_y1_output_root_mean_squared_error: 0.6693 - val_y2_output_root_mean_squared_error: 1.5048
# Epoch 97/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.5997 - y1_output_loss: 0.6043 - y2_output_loss: 2.0001 - y1_output_root_mean_squared_error: 0.7793 - y2_output_root_mean_squared_error: 1.4116 - val_loss: 3.2031 - val_y1_output_loss: 0.4776 - val_y2_output_loss: 2.7405 - val_y1_output_root_mean_squared_error: 0.6980 - val_y2_output_root_mean_squared_error: 1.6480
# Epoch 98/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.7319 - y1_output_loss: 0.6101 - y2_output_loss: 2.1307 - y1_output_root_mean_squared_error: 0.7828 - y2_output_root_mean_squared_error: 1.4557 - val_loss: 7.5745 - val_y1_output_loss: 0.8185 - val_y2_output_loss: 6.5666 - val_y1_output_root_mean_squared_error: 0.9126 - val_y2_output_root_mean_squared_error: 2.5965
# Epoch 99/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.9378 - y1_output_loss: 0.6121 - y2_output_loss: 2.3028 - y1_output_root_mean_squared_error: 0.7853 - y2_output_root_mean_squared_error: 1.5235 - val_loss: 2.9538 - val_y1_output_loss: 0.5844 - val_y2_output_loss: 2.2815 - val_y1_output_root_mean_squared_error: 0.7740 - val_y2_output_root_mean_squared_error: 1.5345
# Epoch 100/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.6973 - y1_output_loss: 0.9212 - y2_output_loss: 2.7563 - y1_output_root_mean_squared_error: 0.9627 - y2_output_root_mean_squared_error: 1.6645 - val_loss: 3.2108 - val_y1_output_loss: 0.5966 - val_y2_output_loss: 2.5202 - val_y1_output_root_mean_squared_error: 0.7827 - val_y2_output_root_mean_squared_error: 1.6119
# Epoch 101/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.3186 - y1_output_loss: 1.1187 - y2_output_loss: 4.1655 - y1_output_root_mean_squared_error: 1.0597 - y2_output_root_mean_squared_error: 2.0483 - val_loss: 5.7513 - val_y1_output_loss: 0.4756 - val_y2_output_loss: 5.1082 - val_y1_output_root_mean_squared_error: 0.6995 - val_y2_output_root_mean_squared_error: 2.2939
# Epoch 102/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.1069 - y1_output_loss: 1.0750 - y2_output_loss: 3.0018 - y1_output_root_mean_squared_error: 1.0391 - y2_output_root_mean_squared_error: 1.7399 - val_loss: 3.5137 - val_y1_output_loss: 0.5384 - val_y2_output_loss: 2.8639 - val_y1_output_root_mean_squared_error: 0.7449 - val_y2_output_root_mean_squared_error: 1.7201
# Epoch 103/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.5192 - y1_output_loss: 0.5526 - y2_output_loss: 1.9473 - y1_output_root_mean_squared_error: 0.7455 - y2_output_root_mean_squared_error: 1.4012 - val_loss: 2.5195 - val_y1_output_loss: 0.4770 - val_y2_output_loss: 2.0430 - val_y1_output_root_mean_squared_error: 0.7020 - val_y2_output_root_mean_squared_error: 1.4237
# Epoch 104/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.4696 - y1_output_loss: 0.5766 - y2_output_loss: 1.8869 - y1_output_root_mean_squared_error: 0.7612 - y2_output_root_mean_squared_error: 1.3748 - val_loss: 2.3420 - val_y1_output_loss: 0.5472 - val_y2_output_loss: 1.7612 - val_y1_output_root_mean_squared_error: 0.7442 - val_y2_output_root_mean_squared_error: 1.3372
# Epoch 105/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.3011 - y1_output_loss: 0.7335 - y2_output_loss: 2.5501 - y1_output_root_mean_squared_error: 0.8600 - y2_output_root_mean_squared_error: 1.6005 - val_loss: 3.5957 - val_y1_output_loss: 0.7557 - val_y2_output_loss: 2.7439 - val_y1_output_root_mean_squared_error: 0.8804 - val_y2_output_root_mean_squared_error: 1.6794
# Epoch 106/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.1191 - y1_output_loss: 1.4355 - y2_output_loss: 4.6357 - y1_output_root_mean_squared_error: 1.2027 - y2_output_root_mean_squared_error: 2.1616 - val_loss: 2.2833 - val_y1_output_loss: 0.3798 - val_y2_output_loss: 1.9112 - val_y1_output_root_mean_squared_error: 0.6213 - val_y2_output_root_mean_squared_error: 1.3774
# Epoch 107/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.2109 - y1_output_loss: 0.6069 - y2_output_loss: 2.5837 - y1_output_root_mean_squared_error: 0.7814 - y2_output_root_mean_squared_error: 1.6125 - val_loss: 2.5194 - val_y1_output_loss: 0.5214 - val_y2_output_loss: 2.0025 - val_y1_output_root_mean_squared_error: 0.7267 - val_y2_output_root_mean_squared_error: 1.4111
# Epoch 108/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.4426 - y1_output_loss: 0.5268 - y2_output_loss: 1.9016 - y1_output_root_mean_squared_error: 0.7276 - y2_output_root_mean_squared_error: 1.3832 - val_loss: 2.7798 - val_y1_output_loss: 0.6507 - val_y2_output_loss: 2.0992 - val_y1_output_root_mean_squared_error: 0.8187 - val_y2_output_root_mean_squared_error: 1.4524
# Epoch 109/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.4653 - y1_output_loss: 0.5119 - y2_output_loss: 1.9508 - y1_output_root_mean_squared_error: 0.7158 - y2_output_root_mean_squared_error: 1.3975 - val_loss: 2.4397 - val_y1_output_loss: 0.5638 - val_y2_output_loss: 1.8408 - val_y1_output_root_mean_squared_error: 0.7619 - val_y2_output_root_mean_squared_error: 1.3635
# Epoch 110/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.2920 - y1_output_loss: 0.5010 - y2_output_loss: 1.7923 - y1_output_root_mean_squared_error: 0.7111 - y2_output_root_mean_squared_error: 1.3366 - val_loss: 3.0092 - val_y1_output_loss: 0.4645 - val_y2_output_loss: 2.4475 - val_y1_output_root_mean_squared_error: 0.6883 - val_y2_output_root_mean_squared_error: 1.5923
# Epoch 111/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.5391 - y1_output_loss: 0.5535 - y2_output_loss: 1.9630 - y1_output_root_mean_squared_error: 0.7471 - y2_output_root_mean_squared_error: 1.4075 - val_loss: 2.1085 - val_y1_output_loss: 0.4085 - val_y2_output_loss: 1.6799 - val_y1_output_root_mean_squared_error: 0.6490 - val_y2_output_root_mean_squared_error: 1.2990
# Epoch 112/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.8742 - y1_output_loss: 0.5911 - y2_output_loss: 2.2626 - y1_output_root_mean_squared_error: 0.7716 - y2_output_root_mean_squared_error: 1.5096 - val_loss: 2.2746 - val_y1_output_loss: 0.3421 - val_y2_output_loss: 1.8546 - val_y1_output_root_mean_squared_error: 0.5955 - val_y2_output_root_mean_squared_error: 1.3856
# Epoch 113/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.5804 - y1_output_loss: 0.5729 - y2_output_loss: 1.9951 - y1_output_root_mean_squared_error: 0.7589 - y2_output_root_mean_squared_error: 1.4158 - val_loss: 2.6549 - val_y1_output_loss: 0.4417 - val_y2_output_loss: 2.1330 - val_y1_output_root_mean_squared_error: 0.6692 - val_y2_output_root_mean_squared_error: 1.4856
# Epoch 114/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.4143 - y1_output_loss: 0.4644 - y2_output_loss: 1.9388 - y1_output_root_mean_squared_error: 0.6842 - y2_output_root_mean_squared_error: 1.3950 - val_loss: 2.8003 - val_y1_output_loss: 0.3289 - val_y2_output_loss: 2.3738 - val_y1_output_root_mean_squared_error: 0.5821 - val_y2_output_root_mean_squared_error: 1.5689
# Epoch 115/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.6819 - y1_output_loss: 0.5304 - y2_output_loss: 2.1895 - y1_output_root_mean_squared_error: 0.7272 - y2_output_root_mean_squared_error: 1.4674 - val_loss: 10.4002 - val_y1_output_loss: 0.8560 - val_y2_output_loss: 9.2867 - val_y1_output_root_mean_squared_error: 0.9393 - val_y2_output_root_mean_squared_error: 3.0851
# Epoch 116/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.7550 - y1_output_loss: 0.8806 - y2_output_loss: 2.8537 - y1_output_root_mean_squared_error: 0.9402 - y2_output_root_mean_squared_error: 1.6944 - val_loss: 2.1024 - val_y1_output_loss: 0.3433 - val_y2_output_loss: 1.7099 - val_y1_output_root_mean_squared_error: 0.5962 - val_y2_output_root_mean_squared_error: 1.3217
# Epoch 117/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.8328 - y1_output_loss: 0.6305 - y2_output_loss: 2.1955 - y1_output_root_mean_squared_error: 0.7970 - y2_output_root_mean_squared_error: 1.4824 - val_loss: 1.9760 - val_y1_output_loss: 0.3760 - val_y2_output_loss: 1.5687 - val_y1_output_root_mean_squared_error: 0.6217 - val_y2_output_root_mean_squared_error: 1.2608
# Epoch 118/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.7100 - y1_output_loss: 0.5612 - y2_output_loss: 2.2006 - y1_output_root_mean_squared_error: 0.7330 - y2_output_root_mean_squared_error: 1.4740 - val_loss: 13.8770 - val_y1_output_loss: 3.0507 - val_y2_output_loss: 10.5646 - val_y1_output_root_mean_squared_error: 1.7527 - val_y2_output_root_mean_squared_error: 3.2871
# Epoch 119/500
# 614/614 [==============================] - 0s 166us/sample - loss: 3.9745 - y1_output_loss: 0.8649 - y2_output_loss: 3.1044 - y1_output_root_mean_squared_error: 0.9307 - y2_output_root_mean_squared_error: 1.7630 - val_loss: 4.2957 - val_y1_output_loss: 0.3639 - val_y2_output_loss: 3.9772 - val_y1_output_root_mean_squared_error: 0.6116 - val_y2_output_root_mean_squared_error: 1.9803
# Epoch 120/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.0119 - y1_output_loss: 0.4195 - y2_output_loss: 1.5949 - y1_output_root_mean_squared_error: 0.6448 - y2_output_root_mean_squared_error: 1.2634 - val_loss: 2.2578 - val_y1_output_loss: 0.4562 - val_y2_output_loss: 1.7584 - val_y1_output_root_mean_squared_error: 0.6835 - val_y2_output_root_mean_squared_error: 1.3381
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.9193 - y1_output_loss: 0.2165 - y2_output_loss: 0.6997 - y1_output_root_mean_squared_error: 0.4657 - y2_output_root_mean_squared_error: 0.8381 - val_loss: 0.8598 - val_y1_output_loss: 0.1607 - val_y2_output_loss: 0.6709 - val_y1_output_root_mean_squared_error: 0.4079 - val_y2_output_root_mean_squared_error: 0.8327
# Epoch 462/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3850 - y1_output_loss: 0.1175 - y2_output_loss: 0.2645 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.5163 - val_loss: 0.7436 - val_y1_output_loss: 0.1792 - val_y2_output_loss: 0.5396 - val_y1_output_root_mean_squared_error: 0.4304 - val_y2_output_root_mean_squared_error: 0.7472
# Epoch 463/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3420 - y1_output_loss: 0.1181 - y2_output_loss: 0.2233 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.4747 - val_loss: 0.7893 - val_y1_output_loss: 0.2545 - val_y2_output_loss: 0.5156 - val_y1_output_root_mean_squared_error: 0.5063 - val_y2_output_root_mean_squared_error: 0.7300
# Epoch 464/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.4436 - y1_output_loss: 0.1161 - y2_output_loss: 0.3290 - y1_output_root_mean_squared_error: 0.3400 - y2_output_root_mean_squared_error: 0.5727 - val_loss: 1.4008 - val_y1_output_loss: 0.1951 - val_y2_output_loss: 1.1827 - val_y1_output_root_mean_squared_error: 0.4475 - val_y2_output_root_mean_squared_error: 1.0957
# Epoch 465/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4115 - y1_output_loss: 0.1224 - y2_output_loss: 0.2903 - y1_output_root_mean_squared_error: 0.3509 - y2_output_root_mean_squared_error: 0.5370 - val_loss: 0.7971 - val_y1_output_loss: 0.1480 - val_y2_output_loss: 0.6353 - val_y1_output_root_mean_squared_error: 0.3897 - val_y2_output_root_mean_squared_error: 0.8033
# Epoch 466/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.3559 - y1_output_loss: 0.1110 - y2_output_loss: 0.2427 - y1_output_root_mean_squared_error: 0.3331 - y2_output_root_mean_squared_error: 0.4949 - val_loss: 0.8185 - val_y1_output_loss: 0.2380 - val_y2_output_loss: 0.5567 - val_y1_output_root_mean_squared_error: 0.4926 - val_y2_output_root_mean_squared_error: 0.7588
# Epoch 467/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3000 - y1_output_loss: 0.1100 - y2_output_loss: 0.1902 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.4347 - val_loss: 0.7688 - val_y1_output_loss: 0.1730 - val_y2_output_loss: 0.5762 - val_y1_output_root_mean_squared_error: 0.4232 - val_y2_output_root_mean_squared_error: 0.7679
# Epoch 468/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4404 - y1_output_loss: 0.1314 - y2_output_loss: 0.3057 - y1_output_root_mean_squared_error: 0.3634 - y2_output_root_mean_squared_error: 0.5553 - val_loss: 0.7794 - val_y1_output_loss: 0.1919 - val_y2_output_loss: 0.5630 - val_y1_output_root_mean_squared_error: 0.4463 - val_y2_output_root_mean_squared_error: 0.7618
# Epoch 469/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3267 - y1_output_loss: 0.1059 - y2_output_loss: 0.2243 - y1_output_root_mean_squared_error: 0.3252 - y2_output_root_mean_squared_error: 0.4700 - val_loss: 1.0675 - val_y1_output_loss: 0.2009 - val_y2_output_loss: 0.8540 - val_y1_output_root_mean_squared_error: 0.4496 - val_y2_output_root_mean_squared_error: 0.9303
# Epoch 470/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3548 - y1_output_loss: 0.1164 - y2_output_loss: 0.2389 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.4876 - val_loss: 0.8570 - val_y1_output_loss: 0.1717 - val_y2_output_loss: 0.6631 - val_y1_output_root_mean_squared_error: 0.4217 - val_y2_output_root_mean_squared_error: 0.8241
# Epoch 471/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3921 - y1_output_loss: 0.1144 - y2_output_loss: 0.2756 - y1_output_root_mean_squared_error: 0.3390 - y2_output_root_mean_squared_error: 0.5264 - val_loss: 0.7765 - val_y1_output_loss: 0.1859 - val_y2_output_loss: 0.5679 - val_y1_output_root_mean_squared_error: 0.4350 - val_y2_output_root_mean_squared_error: 0.7663
# Epoch 472/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3655 - y1_output_loss: 0.1265 - y2_output_loss: 0.2443 - y1_output_root_mean_squared_error: 0.3516 - y2_output_root_mean_squared_error: 0.4919 - val_loss: 1.5073 - val_y1_output_loss: 0.3268 - val_y2_output_loss: 1.1573 - val_y1_output_root_mean_squared_error: 0.5741 - val_y2_output_root_mean_squared_error: 1.0852
# Epoch 473/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3799 - y1_output_loss: 0.1149 - y2_output_loss: 0.2672 - y1_output_root_mean_squared_error: 0.3393 - y2_output_root_mean_squared_error: 0.5146 - val_loss: 1.4186 - val_y1_output_loss: 0.1802 - val_y2_output_loss: 1.2091 - val_y1_output_root_mean_squared_error: 0.4297 - val_y2_output_root_mean_squared_error: 1.1108
# Epoch 474/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4881 - y1_output_loss: 0.1480 - y2_output_loss: 0.3612 - y1_output_root_mean_squared_error: 0.3846 - y2_output_root_mean_squared_error: 0.5833 - val_loss: 6.2441 - val_y1_output_loss: 0.6822 - val_y2_output_loss: 5.6819 - val_y1_output_root_mean_squared_error: 0.8196 - val_y2_output_root_mean_squared_error: 2.3606
# Epoch 475/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.7790 - y1_output_loss: 0.1862 - y2_output_loss: 0.5883 - y1_output_root_mean_squared_error: 0.4319 - y2_output_root_mean_squared_error: 0.7697 - val_loss: 0.8322 - val_y1_output_loss: 0.1974 - val_y2_output_loss: 0.6242 - val_y1_output_root_mean_squared_error: 0.4449 - val_y2_output_root_mean_squared_error: 0.7964
# Epoch 476/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3211 - y1_output_loss: 0.1113 - y2_output_loss: 0.2081 - y1_output_root_mean_squared_error: 0.3349 - y2_output_root_mean_squared_error: 0.4571 - val_loss: 0.7180 - val_y1_output_loss: 0.1574 - val_y2_output_loss: 0.5427 - val_y1_output_root_mean_squared_error: 0.3985 - val_y2_output_root_mean_squared_error: 0.7478
# Epoch 477/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3896 - y1_output_loss: 0.1241 - y2_output_loss: 0.2651 - y1_output_root_mean_squared_error: 0.3531 - y2_output_root_mean_squared_error: 0.5147 - val_loss: 1.1437 - val_y1_output_loss: 0.2610 - val_y2_output_loss: 0.8581 - val_y1_output_root_mean_squared_error: 0.5131 - val_y2_output_root_mean_squared_error: 0.9383
# Epoch 478/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.3941 - y1_output_loss: 0.1216 - y2_output_loss: 0.2695 - y1_output_root_mean_squared_error: 0.3497 - y2_output_root_mean_squared_error: 0.5214 - val_loss: 0.7864 - val_y1_output_loss: 0.1647 - val_y2_output_loss: 0.5972 - val_y1_output_root_mean_squared_error: 0.4111 - val_y2_output_root_mean_squared_error: 0.7858
# Epoch 479/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3934 - y1_output_loss: 0.1272 - y2_output_loss: 0.2668 - y1_output_root_mean_squared_error: 0.3548 - y2_output_root_mean_squared_error: 0.5172 - val_loss: 0.7794 - val_y1_output_loss: 0.2477 - val_y2_output_loss: 0.5064 - val_y1_output_root_mean_squared_error: 0.5063 - val_y2_output_root_mean_squared_error: 0.7232
# Epoch 480/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.4424 - y1_output_loss: 0.1272 - y2_output_loss: 0.3129 - y1_output_root_mean_squared_error: 0.3578 - y2_output_root_mean_squared_error: 0.5607 - val_loss: 0.7712 - val_y1_output_loss: 0.1592 - val_y2_output_loss: 0.5895 - val_y1_output_root_mean_squared_error: 0.4060 - val_y2_output_root_mean_squared_error: 0.7787
# Epoch 481/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3356 - y1_output_loss: 0.1212 - y2_output_loss: 0.2173 - y1_output_root_mean_squared_error: 0.3487 - y2_output_root_mean_squared_error: 0.4627 - val_loss: 1.3662 - val_y1_output_loss: 0.1828 - val_y2_output_loss: 1.1678 - val_y1_output_root_mean_squared_error: 0.4352 - val_y2_output_root_mean_squared_error: 1.0848
# Epoch 482/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.4802 - y1_output_loss: 0.1379 - y2_output_loss: 0.3441 - y1_output_root_mean_squared_error: 0.3720 - y2_output_root_mean_squared_error: 0.5846 - val_loss: 0.9359 - val_y1_output_loss: 0.1675 - val_y2_output_loss: 0.7572 - val_y1_output_root_mean_squared_error: 0.4124 - val_y2_output_root_mean_squared_error: 0.8751
# Epoch 483/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3770 - y1_output_loss: 0.1250 - y2_output_loss: 0.2498 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.5015 - val_loss: 0.7703 - val_y1_output_loss: 0.1698 - val_y2_output_loss: 0.5819 - val_y1_output_root_mean_squared_error: 0.4135 - val_y2_output_root_mean_squared_error: 0.7742
# Epoch 484/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.3735 - y1_output_loss: 0.1245 - y2_output_loss: 0.2515 - y1_output_root_mean_squared_error: 0.3502 - y2_output_root_mean_squared_error: 0.5008 - val_loss: 1.1173 - val_y1_output_loss: 0.3046 - val_y2_output_loss: 0.7898 - val_y1_output_root_mean_squared_error: 0.5557 - val_y2_output_root_mean_squared_error: 0.8992
# Epoch 485/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3915 - y1_output_loss: 0.1261 - y2_output_loss: 0.2677 - y1_output_root_mean_squared_error: 0.3517 - y2_output_root_mean_squared_error: 0.5175 - val_loss: 1.4227 - val_y1_output_loss: 0.2951 - val_y2_output_loss: 1.1112 - val_y1_output_root_mean_squared_error: 0.5509 - val_y2_output_root_mean_squared_error: 1.0579
# Epoch 486/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3411 - y1_output_loss: 0.1122 - y2_output_loss: 0.2337 - y1_output_root_mean_squared_error: 0.3321 - y2_output_root_mean_squared_error: 0.4804 - val_loss: 2.4254 - val_y1_output_loss: 0.4612 - val_y2_output_loss: 1.9385 - val_y1_output_root_mean_squared_error: 0.6889 - val_y2_output_root_mean_squared_error: 1.3968
# Epoch 487/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4160 - y1_output_loss: 0.1238 - y2_output_loss: 0.2922 - y1_output_root_mean_squared_error: 0.3523 - y2_output_root_mean_squared_error: 0.5402 - val_loss: 0.9049 - val_y1_output_loss: 0.2312 - val_y2_output_loss: 0.6500 - val_y1_output_root_mean_squared_error: 0.4900 - val_y2_output_root_mean_squared_error: 0.8154
# Epoch 488/500
# 614/614 [==============================] - 0s 183us/sample - loss: 0.5259 - y1_output_loss: 0.1377 - y2_output_loss: 0.3888 - y1_output_root_mean_squared_error: 0.3698 - y2_output_root_mean_squared_error: 0.6238 - val_loss: 1.8124 - val_y1_output_loss: 0.5670 - val_y2_output_loss: 1.2103 - val_y1_output_root_mean_squared_error: 0.7636 - val_y2_output_root_mean_squared_error: 1.1087
# Epoch 489/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.4772 - y1_output_loss: 0.1365 - y2_output_loss: 0.3384 - y1_output_root_mean_squared_error: 0.3700 - y2_output_root_mean_squared_error: 0.5833 - val_loss: 0.8784 - val_y1_output_loss: 0.2174 - val_y2_output_loss: 0.6485 - val_y1_output_root_mean_squared_error: 0.4641 - val_y2_output_root_mean_squared_error: 0.8143
# Epoch 490/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.4219 - y1_output_loss: 0.1366 - y2_output_loss: 0.2869 - y1_output_root_mean_squared_error: 0.3663 - y2_output_root_mean_squared_error: 0.5364 - val_loss: 1.3486 - val_y1_output_loss: 0.4170 - val_y2_output_loss: 0.8920 - val_y1_output_root_mean_squared_error: 0.6528 - val_y2_output_root_mean_squared_error: 0.9605
# Epoch 491/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3692 - y1_output_loss: 0.1188 - y2_output_loss: 0.2493 - y1_output_root_mean_squared_error: 0.3448 - y2_output_root_mean_squared_error: 0.5003 - val_loss: 0.8760 - val_y1_output_loss: 0.2025 - val_y2_output_loss: 0.6546 - val_y1_output_root_mean_squared_error: 0.4571 - val_y2_output_root_mean_squared_error: 0.8168
# Epoch 492/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3615 - y1_output_loss: 0.1208 - y2_output_loss: 0.2418 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.4911 - val_loss: 0.8461 - val_y1_output_loss: 0.2242 - val_y2_output_loss: 0.5961 - val_y1_output_root_mean_squared_error: 0.4795 - val_y2_output_root_mean_squared_error: 0.7849
# Epoch 493/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.4375 - y1_output_loss: 0.1186 - y2_output_loss: 0.3154 - y1_output_root_mean_squared_error: 0.3457 - y2_output_root_mean_squared_error: 0.5639 - val_loss: 0.6463 - val_y1_output_loss: 0.1564 - val_y2_output_loss: 0.4696 - val_y1_output_root_mean_squared_error: 0.4006 - val_y2_output_root_mean_squared_error: 0.6970
# Epoch 494/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4633 - y1_output_loss: 0.1372 - y2_output_loss: 0.3253 - y1_output_root_mean_squared_error: 0.3705 - y2_output_root_mean_squared_error: 0.5710 - val_loss: 1.0921 - val_y1_output_loss: 0.2873 - val_y2_output_loss: 0.7856 - val_y1_output_root_mean_squared_error: 0.5399 - val_y2_output_root_mean_squared_error: 0.8948
# Epoch 495/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.4196 - y1_output_loss: 0.1424 - y2_output_loss: 0.2760 - y1_output_root_mean_squared_error: 0.3780 - y2_output_root_mean_squared_error: 0.5261 - val_loss: 0.7999 - val_y1_output_loss: 0.1995 - val_y2_output_loss: 0.5792 - val_y1_output_root_mean_squared_error: 0.4481 - val_y2_output_root_mean_squared_error: 0.7740
# Epoch 496/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3249 - y1_output_loss: 0.1181 - y2_output_loss: 0.2053 - y1_output_root_mean_squared_error: 0.3439 - y2_output_root_mean_squared_error: 0.4546 - val_loss: 0.7550 - val_y1_output_loss: 0.1876 - val_y2_output_loss: 0.5441 - val_y1_output_root_mean_squared_error: 0.4382 - val_y2_output_root_mean_squared_error: 0.7503
# Epoch 497/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.3342 - y1_output_loss: 0.1202 - y2_output_loss: 0.2120 - y1_output_root_mean_squared_error: 0.3479 - y2_output_root_mean_squared_error: 0.4617 - val_loss: 0.9121 - val_y1_output_loss: 0.2679 - val_y2_output_loss: 0.6188 - val_y1_output_root_mean_squared_error: 0.5238 - val_y2_output_root_mean_squared_error: 0.7986
# Epoch 498/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3171 - y1_output_loss: 0.1106 - y2_output_loss: 0.2075 - y1_output_root_mean_squared_error: 0.3313 - y2_output_root_mean_squared_error: 0.4553 - val_loss: 1.1481 - val_y1_output_loss: 0.2949 - val_y2_output_loss: 0.8243 - val_y1_output_root_mean_squared_error: 0.5483 - val_y2_output_root_mean_squared_error: 0.9206
# Epoch 499/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.3714 - y1_output_loss: 0.1262 - y2_output_loss: 0.2430 - y1_output_root_mean_squared_error: 0.3567 - y2_output_root_mean_squared_error: 0.4942 - val_loss: 0.6911 - val_y1_output_loss: 0.1605 - val_y2_output_loss: 0.5088 - val_y1_output_root_mean_squared_error: 0.4062 - val_y2_output_root_mean_squared_error: 0.7253
# Epoch 500/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.5069 - y1_output_loss: 0.1591 - y2_output_loss: 0.3437 - y1_output_root_mean_squared_error: 0.4001 - y2_output_root_mean_squared_error: 0.5890 - val_loss: 0.6854 - val_y1_output_loss: 0.1623 - val_y2_output_loss: 0.5017 - val_y1_output_root_mean_squared_error: 0.4077 - val_y2_output_root_mean_squared_error: 0.7206

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 46us/sample - loss: 0.6854 - y1_output_loss: 0.1667 - y2_output_loss: 0.5276 - y1_output_root_mean_squared_error: 0.4077 - y2_output_root_mean_squared_error: 0.7206
# Loss = 0.6854412524731128, Y1_loss = 0.1667241007089615, Y1_mse = 0.4077053666114807, Y2_loss = 0.5276444554328918, Y2_mse = 0.7205675840377808

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
